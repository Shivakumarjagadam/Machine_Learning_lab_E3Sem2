# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.naive_bayes import BernoulliNB,MultinomialNB
from sklearn.metrics import accuracy_score,classification_report

# %%
#3. load 20 news group train subset
train_df = pd.read_csv('nlp_train.csv')
train_df.head(20)
# Out:
#                                                  text  target  \
# 0   I was wondering if anyone out there could enli...       7
# 1   A fair number of brave souls who upgraded thei...       4
# 2   well folks, my mac plus finally gave up the gh...       4
# 3   \nDo you have Weitek's address/phone number?  ...       1
# 4   From article <C5owCB.n3p@world.std.com>, by to...      14
# 5   \n\n\n\n\nOf course.  The term must be rigidly...      16
# 6   There were a few people who responded to my re...      13
# 7                                                 ...       3
# 8   I have win 3.0 and downloaded several icons an...       2
# 9   \n\n\nI've had the board for over a year, and ...       4
# 10  I have a line on a Ducati 900GTS 1978 model wi...       8
# 11  \nYep, that's pretty much it. I'm not a Jew bu...      19
# 12                                               --\n       4
# 13  \n   {Description of "External Tank" option fo...      14
# ...

# %%
test_df = pd.read_csv('nlp_test.csv')
test_df.head(20)
# Out:
#                                                  text  target  \
# 0   I am a little confused on all of the models of...       7
# 1   I'm not familiar at all with the format of the...       5
# 2                                 \nIn a word, yes.\n       0
# 3   \nThey were attacking the Iraqis to drive them...      17
# 4   \nI've just spent two solid months arguing tha...      19
# 5   \nElisabeth, let's set the record straight for...      13
# 6   Dishonest money dwindles away, but he who gath...      15
# 7   A friend of mine managed to get a copy of a co...      15
# 8   Hi,\n\n   We have a requirement for dynamicall...       5
# 9   :  \n: well, i have lots of experience with sc...       1
# 10  I have uploaded the Windows On-Line Review sha...       2
# 11  Most graphics systems I have seen have drawing...       5
# 12  \nYou *know* that putting something like this ...      17
# 13  \nAccusation?  I thought it was a recommendati...       8
# ...

# %%
# 5. Print all target labels
# train_df['category'].unique()
print(test_df['category'].unique())
# Out:
# ['rec.autos' 'comp.windows.x' 'alt.atheism' 'talk.politics.mideast'
#  'talk.religion.misc' 'sci.med' 'soc.religion.christian' 'comp.graphics'
#  'comp.os.ms-windows.misc' 'rec.motorcycles' 'comp.sys.mac.hardware'
#  'misc.forsale' 'talk.politics.guns' 'sci.space'
#  'comp.sys.ibm.pc.hardware' 'sci.crypt' 'rec.sport.baseball'
#  'rec.sport.hockey' 'talk.politics.misc' 'sci.electronics']

# %%
#  6. Prepare subset of subset categories alt.athesim, comp.graphics and sci.space
cols = ['alt.athesim', 'comp.graphics','sci.space']

train_subs = train_df[train_df['category'].isin(cols)]
print(train_subs.head())

test_subs = test_df[test_df['category'].isin(cols)]
print(test_subs.head())
# Out:
#                                                  text  target       category
# 3   \nDo you have Weitek's address/phone number?  ...       1  comp.graphics
# 4   From article <C5owCB.n3p@world.std.com>, by to...      14      sci.space
# 13  \n   {Description of "External Tank" option fo...      14      sci.space
# 16  \nI certainly do use it whenever I have to do ...       1  comp.graphics
# 25  Hello,\n     I am looking to add voice input c...       1  comp.graphics
#                                                  text  target       category
# 9   :  \n: well, i have lots of experience with sc...       1  comp.graphics
# 17  Hello,\ni'm interested in those devices too.\n...       1  comp.graphics
# 20  This is an invitation to send articles to the ...       1  comp.graphics
# 23  \n\nWhy not design the solar arrays to be deta...      14      sci.space
# 34  Forwarded from Neal Ausman, Galileo Mission Di...      14      sci.space

# %%
# 7, 8 Load train subset with the above three categorie

print("trainsubs:",train_subs.head(20))

print("test: ",test_subs.head(20))
# Out:
# trainsubs:                                                   text  target       category
# 3    \nDo you have Weitek's address/phone number?  ...       1  comp.graphics
# 4    From article <C5owCB.n3p@world.std.com>, by to...      14      sci.space
# 13   \n   {Description of "External Tank" option fo...      14      sci.space
# 16   \nI certainly do use it whenever I have to do ...       1  comp.graphics
# 25   Hello,\n     I am looking to add voice input c...       1  comp.graphics
# 49   Pat sez;\n\nYeah, but a windscreen cut down mo...      14      sci.space
# 59   Archive-name: space/new_probes\nLast-modified:...      14      sci.space
# 82   Australian Pattern Recognition Society\n\n    ...       1  comp.graphics
# 87   \nHi Noel,\n\nI've made some attempts to write...       1  comp.graphics
# 99   : Currently, I use a shareware program called ...       1  comp.graphics
# 108  i am sorry, but this genoa card does nothing t...       1  comp.graphics
# ...

# %%
# 9 print train set category labels...
train_subs['category'].unique()
# Out:
# array(['comp.graphics', 'sci.space'], dtype=object)

# %%
print("5th article : \n" , train_subs["text"].iloc[4])
# Out:
# 5th article :
#  Hello,
#      I am looking to add voice input capability to a user interface I am
# developing on an HP730 (UNIX) workstation.  I would greatly appreciate
# information anyone would care to offer about voice input systems that are
# easily accessible from the UNIX environment.
#
#      The names or adresses of applicable vendors, as well as any
# experiences you have had with specific systems, would be very helpful.
#
#      Please respond via email; I will post a summary if there is
# sufficient interest.
#
#
# Thanks,
# Ken
#
#
# P.S.  I have found several impressive systems for IBM PC's, but I would
# like to avoid the hassle of purchasing and maintaining a separate PC if
# at all possible.
#
# -------------------------------------------------------------------------------
# Ken Hinckley (kph2q@virginia.edu)
# University of Virginia
# Neurosurgical Visualization Laboratory

# %%
print("5th article : " , train_subs.iloc[4,0])
# Out:
# 5th article :  Hello,
#      I am looking to add voice input capability to a user interface I am
# developing on an HP730 (UNIX) workstation.  I would greatly appreciate
# information anyone would care to offer about voice input systems that are
# easily accessible from the UNIX environment.
#
#      The names or adresses of applicable vendors, as well as any
# experiences you have had with specific systems, would be very helpful.
#
#      Please respond via email; I will post a summary if there is
# sufficient interest.
#
#
# Thanks,
# Ken
#
#
# P.S.  I have found several impressive systems for IBM PC's, but I would
# like to avoid the hassle of purchasing and maintaining a separate PC if
# at all possible.
#
# -------------------------------------------------------------------------------
# Ken Hinckley (kph2q@virginia.edu)
# University of Virginia
# Neurosurgical Visualization Laboratory

# %%
# 13. By using count vectorizor train data into numerical format considering
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

cv = CountVectorizer()

x_train_count = cv.fit_transform(train_subs)

# Convert the sparse matrix into an array to see the result
x_train_array = x_train_count.toarray()

x_train_array.shape
x_train_array
# Out:
# array([[0, 0, 1],
#        [0, 1, 0],
#        [1, 0, 0]], dtype=int64)

# %%
# tharun
# 13. By using count vectorizor train data into numerical format considering

# Remove rows where 'text' or 'category' is NaN
train_subs = train_subs.dropna(subset=['text', 'category'])

# Now apply CountVectorizer
cv = CountVectorizer()
x_train = cv.fit_transform(train_subs["text"])
y_train = train_subs["category"]

print(x_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 110339 stored elements and shape (1152, 19493)>
#   Coords	Values
#   (0, 6485)	1
#   (0, 19415)	1
#   (0, 8937)	1
#   (0, 18964)	1
#   (0, 2271)	1
#   (0, 13458)	1
#   (0, 12573)	1
#   (0, 10895)	1
#   (0, 17665)	1
#   (0, 8406)	1
#   (0, 16282)	1
#   (0, 9707)	1
#   (0, 2098)	1
#   (0, 17533)	1
#   (0, 4546)	1
#   (1, 19415)	1
#   (1, 8937)	1
#   (1, 8137)	1
#   (1, 3024)	1
#   (1, 4101)	1
#   (1, 12154)	1
#   (1, 19198)	2
#   (1, 16672)	2
#   (1, 4879)	2
#   (1, 4089)	1
#   :	:
#   (1151, 19024)	1
#   (1151, 12495)	1
#   (1151, 13697)	1
#   (1151, 11506)	1
#   (1151, 12983)	1
#   (1151, 2629)	1
#   (1151, 11462)	1
#   (1151, 7629)	1
#   (1151, 6404)	1
#   (1151, 13705)	2
#   (1151, 19217)	1
#   (1151, 5399)	1
#   (1151, 14965)	1
#   (1151, 14406)	1
#   (1151, 12255)	1
#   (1151, 16462)	2
#   (1151, 7397)	1
#   (1151, 8879)	1
#   (1151, 18248)	1
#   (1151, 19243)	1
#   (1151, 16426)	1
#   (1151, 16719)	1
# ...

# %%
from sklearn.naive_bayes import BernoulliNB,MultinomialNB

model = BernoulliNB()

model.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
test_subs.isna().sum()
# Out:
# text        16
# target       0
# category     0
# dtype: int64

# %%
# remove null values from test...
x_test = test_subs.dropna()

# %%
x_test.isna().sum()
# Out:
# 0

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import accuracy_score
import pandas as pd

# Load train and test data
train_df = pd.read_csv("nlp_train.csv")
test_df = pd.read_csv("nlp_test.csv")

# Handle missing values by filling NaN with empty string
train_df['text'] = train_df['text'].fillna('')
test_df['text'] = test_df['text'].fillna('')

# Prepare features and labels for train data
x_train = train_df["text"]
y_train = train_df["category"]

# Prepare features and labels for test data
x_test = test_df["text"]
y_test = test_df["category"]

# Initialize CountVectorizer
cv = CountVectorizer()  # 'binary=True' to make it binary features

# Fit the vectorizer on the train data and transform it into numeric format
x_train_count = cv.fit_transform(x_train)

# Transform the test data into numeric format using the same vocabulary from the train data

# Initialize Bernoulli Naive Bayes model
# bnb = BernoulliNB()

# Train the model with the transformed train data
model.fit(x_train_count, y_train)

# Predict on the test data
y_pred = model.predict(x_test_count)

# # Evaluate accuracy
# accuracy = accuracy_score(y_test, y_pred)
# print("Test Accuracy of Bernoulli Naive Bayes: ", accuracy)

accuracy_score(y_test,y_pred)
# Out:
# 0.4579129049389272

# %%
from sklearn.naive_bayes import MultinomialNB
mb= MultinomialNB()

mb.fit(x_train_count,y_train)
# Out:
# MultinomialNB()

# %%
y_pred = mb.predict(x_test)
y_pred[:5]
# Out:
# array(['soc.religion.christian', 'comp.graphics',
#        'soc.religion.christian', 'talk.politics.mideast', 'alt.atheism'],
#       dtype='<U24')

# %%
ac = accuracy_score(y_test,y_pred)
ac
# Out:
# 0.5431492299522039
