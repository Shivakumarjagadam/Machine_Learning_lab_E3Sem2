# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Car_sales.csv")
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
# print rows,cols
df.shape

rows,cols=df.shape
print(f"rows:{rows} and cols:{cols}")
# Out:
# rows:157 and cols:15

# %%
cleaned_df=df.drop_duplicates()
cleaned_df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
cleaned_df.shape
# Out:
# (157, 15)

# %%
summaryDF=df.select_dtypes(include='number')
summaryDF.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
# 7. Print number of missing values in each column
df.isna().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
# 8. Drop the column with most missing values

# if now missingValues ,then 1st column defaulty removed..
# before drop..
before=df
print("before drop:")
print(before.info())
# Out:
# before drop:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    object
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   157 non-null    object
#  6   Engine size          157 non-null    object
#  7   Horsepower           157 non-null    object
#  8   Wheelbase            157 non-null    object
#  9   Width                157 non-null    object
#  10  Length               157 non-null    object
#  11  Curb weight          157 non-null    object
#  12  Fuel capacity        157 non-null    object
#  13  Fuel efficiency      157 non-null    object
#  14  Latest Launch        157 non-null    object
# ...

# %%
#continue...
# 8. Drop the column with most missing values

# after drop info...
column_drop = df.isna().sum().idxmax()
afterDrop = df.drop(columns=[column_drop])
print("after drop:")
print(afterDrop.info())
# Out:
# after drop:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Model                157 non-null    object
#  1   Sales in thousands   157 non-null    float64
#  2   4-year resale value  157 non-null    object
#  3   Vehicle type         157 non-null    object
#  4   Price in thousands   157 non-null    object
#  5   Engine size          157 non-null    object
#  6   Horsepower           157 non-null    object
#  7   Wheelbase            157 non-null    object
#  8   Width                157 non-null    object
#  9   Length               157 non-null    object
#  10  Curb weight          157 non-null    object
#  11  Fuel capacity        157 non-null    object
#  12  Fuel efficiency      157 non-null    object
#  13  Latest Launch        157 non-null    object
# dtypes: float64(1), object(13)
# memory usage: 17.3+ KB
# ...

# %%
# 9 Drop the rows with categorical missing values
# lets assing categori cols as..where the columns are in category type..gender,cities ,product_name which are text based..not as number catogy(age,marks..)

category_cols = df.select_dtypes(include="object").columns

cleaned_df = df.dropna(subset=category_cols)
cleaned_df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
# dataframe..
data = {
  'name':['shiva','ajay','rajshekar'],
  'city':['arm','nzb','hyd'],
  'age':[10,20,None],
  'gpa':[1,2,3]
}


data = pd.DataFrame(data)
data
# Out:
#         name city   age  gpa
# 0      shiva  arm  10.0    1
# 1       ajay  nzb  20.0    2
# 2  rajshekar  hyd   NaN    3

# %%
# data['age'].fillna(data['age'].min(), inplace=True)
print(data['age'].unique())
# Out:
# [10. 20. nan]

# %%
# 10. Import the rows with numerical missing values

"""
  df.select_dtypes(include="number").columns: picks only numeric columns.
  
df[numCols].isna(): gives True/False where numeric values are missing.

.any(axis=1): checks if any of the numeric columns are NaN in each row.
"""
# Identify numerical columns (dtype == int64 or float64)
numerical_cols = df.select_dtypes(include=['number']).columns

# Select rows where any numerical column has missing values
df_missing_numerical = df[df[numerical_cols].isnull().any(axis=1)]

# Display the filtered DataFrame
print("\nRows with Missing Numerical Values:")
print(df_missing_numerical)
# df_missing_numerical
# Out:
# Rows with Missing Numerical Values:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
# THARUN

# 11. Sort the data w.r.t price_find the details of the most and the least expensive cars


# Drop rows where 'Price' is missing
df = df.dropna(subset=['Price in thousands'])

# convert price from object type to numeric

df['Price in thousands'] = pd.to_numeric(df['Price in thousands'],errors='coerce')

df_sort_price = df.sort_values(by='Price in thousands')

least_expensive_car = df_sort_price.iloc[0]
most_expensive_car = df_sort_price.iloc[-1]

# print("Least expensive care details : \n\n", least_expensive_car)
print("\n\nMost expensive car details : \n\n",most_expensive_car)
# Out:
# Most expensive car details :
#
#  Manufacturer               Chrysler
# Model                  Town & Country
# Sales in thousands                 53.48
# 4-year resale value                19.54
# Vehicle type                         Car
# Price in thousands                   NaN
# Engine size                            .
# Horsepower                             .
# Wheelbase                              .
# Width                                  .
# Length                                 .
# Curb weight                            .
# Fuel capacity                          .
# Fuel efficiency                        .
# Latest Launch                  13-Jul-15
# Name: 33, dtype: object

# %%
# Drop rows where price is NaN
df_PriceValues = df.dropna(subset=['Price in thousands'])

# Sort by 'Price in thousands' and reassign
df_PriceValues = df_PriceValues.sort_values(by=['Price in thousands'], ascending=True)

# Get least and most expensive car details
least_expen_cars = df_PriceValues.iloc[0]
most_exp_cars = df_PriceValues.iloc[-1]

# Print results
print(f"Least Expensive Car:\n{least_expen_cars}\n")
print("-" * 50)
print(f"Most Expensive Car:\n{most_exp_cars}")
# Out:
# Least Expensive Car:
# Manufacturer               Chevrolet
# Model                  Metro
# Sales in thousands                21.855
# 4-year resale value                 5.16
# Vehicle type                   Passenger
# Price in thousands                 9.235
# Engine size                            1
# Horsepower                            55
# Wheelbase                           93.1
# Width                               62.6
# Length                             149.4
# Curb weight                        1.895
# Fuel capacity                       10.3
# Fuel efficiency                       45
# Latest Launch                  13-Apr-14
# Name: 26, dtype: object
#
# --------------------------------------------------
# Most Expensive Car:
# Manufacturer               Mercedes-Benz
# Model                  CL500
# Sales in thousands                 0.954
# 4-year resale value                    .
# Vehicle type                   Passenger
# ...

# %%
# 12. Write a function to find min and max values of any
# column
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
print(f"max of priceInThoudans:{df['Price in thousands'].max()}")
print(f"min of priceInThoudans:{df['Price in thousands'].min()}")

print(f"max of salesInThoudans:{df['Sales in thousands'].max()}")
print(f"min of salesInThoudans:{df['Sales in thousands'].min()}")
# Out:
# max of priceInThoudans:85.5
# min of priceInThoudans:9.235
# max of salesInThoudans:540.561
# min of salesInThoudans:0.11

# %%
# 13. Call the above function to find min max of horse
# power, length, fuel efficiency...
print(f"horsePower max: {df['Horsepower'].max()} and horsePowermin:{df['Horsepower'].min()}")
# Out:
# horsePower max: 92 and horsePowermin:.

# %%
# Define a function to print min and max of a column
def print_min_max(column_name):
    max_val = df[column_name].max()
    min_val = df[column_name].min()
    print(f"{column_name} - Max: {max_val}, Min: {min_val}")

# Call the function for required columns
print_min_max('Horsepower')
print_min_max('Length')
print_min_max('Fuel efficiency')
# Out:
# Horsepower - Max: 92, Min: .
# Length - Max: 224.5, Min: .
# Fuel efficiency - Max: 45, Min: .

# %%
# 14. Plot histogram of continuous numerical variable :
# price,sales,hoursepower,fuelefficiency

# create numeric cols
nums_cols = df.select_dtypes(include='number').columns

df_nums_cols = df[nums_cols].dropna()

# lets create 2*2 grid plot
fig,axes = plt.subplots(2,2,figsize=(10,8))

axes=axes.flatten() #  # Flatten to 1D array for easy indexing

for i,col in enumerate(df_nums_cols.columns[:4]): #upto 4 cols..
  sns.histplot(df_nums_cols[col],ax=axes[i],kde=True)
  axes[i].set_title(f"{col} Distribution")
  axes[i].set_xlabel(f"{col}")
  axes[i].set_ylabel("freq")
  

plt.tight_layout()
plt.show()

# %%
# 15. Probability density distribution of continuous
# numerical variable-length

# length where diff cars have diff length...

dfLength=df['Length'].dropna()

sns.kdeplot(dfLength,color='green',fill=True)

plt.title("KDE")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 8
#       1 # 15. Probability density distribution of continuous
#       2 # numerical variable-length
#       3
#       4 # length where diff cars have diff length...
#       6 dfLength=df['Length'].dropna()
# ----> 8 sns.kdeplot(dfLength,color='green',fill=True)
#      10 plt.title("KDE")
#      11 plt.tight_layout()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\seaborn\distributions.py:1679, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1676 if ax is None:
#    1677     ax = plt.gca()
# -> 1679 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
# ...

# %%
# 16. Count by category –group by manufacture
df.groupby(by='Manufacturer').size().sort_values()
# Out:
# Manufacturer
# Jaguar            1
# Infiniti          1
# Subaru            2
# Saab              2
# Acura             3
# Lincoln           3
# Jeep              3
# Hyundai           3
# Porsche           3
# BMW               3
# Audi              3
# Buick             4
# Plymouth          4
# Honda             5
# Saturn            5
# Cadillac          5
# Pontiac           6
# Oldsmobile        6
# Lexus             6
# Mercury           6
# Volkswagen        6
# Chrysler          6
# Volvo             6
# Nissan            7
# Mitsubishi        7
# Mercedes-Benz     9
# Chevrolet         9
# Toyota            9
# Ford             11
# Dodge            11
# dtype: int64

# %%
# 17. Select all numerical variables
num_cols=df.select_dtypes(include='number').columns

df[num_cols]
# Out:
#      Sales in thousands  Price in thousands  Horsepower  Length  \
# 0                16.919               21.50         140   172.4
# 1                39.384               28.40         225   192.9
# 3                 8.588               42.00         210   196.6
# 4                20.397               23.99         150   178.0
# 5                18.780               33.95         200   192.0
# ..                  ...                 ...         ...     ...
# 152               3.545               24.40         160   176.6
# 153              15.245               27.50         168   185.9
# 154              17.531               28.80         168   186.2
# 155               3.493               45.50         236   185.7
# 156              18.969               36.00         201   189.8
#
#      Fuel efficiency
# 0               28.0
# 1               25.0
# 3               22.0
# 4               27.0
# 5               22.0
# ..               ...
# 152             25.0
# ...

# %%
# 18. Print correlation coefficient value of price and sales
# df.corr(numeric_only=True)

# df_price = df['Price in thousands'].dropna()
# df_sales =df['Sales in thousands'].dropna()
# correlation = df_price.corr(df_sales)
# correlation

df_cleaned = df[['Price in thousands','Sales in thousands']].dropna()

correlation=df_cleaned['Price in thousands'].corr(df_cleaned['Sales in thousands'])
correlation
# Out:
# -0.3047344541294122

# %%
# 19. Plot correlation of price and sales using scatterplot

# drop null valeus from price and sales...

df_cleaned = df[['Price in thousands','Sales in thousands']].dropna()

plt.figure(figsize=(10,5))
sns.scatterplot(data=df_cleaned,y="Sales in thousands",x="Price in thousands")

plt.title("prie and sal")
plt.xlabel("price in thous")
plt.ylabel("sale sin thous")
plt.grid(True)
plt.show()

# %%
# 20.Pair plot
pairCols = df.select_dtypes(include='number').columns
df_clean = df[pairCols].dropna()
sns.pairplot(data=df_clean)

plt.suptitle('Pair Plot of Selected Features', y=1.02)
plt.show()

# %%
# . Boxplot of sales of different manufacturer
Sales_manu = df[['Sales in thousands','Manufacturer']].dropna()

plt.figure(figsize=(10,10))

sns.boxplot(data=Sales_manu,x="Sales in thousands",y="Manufacturer")
plt.title('Boxplot of Sales by Manufacturer')
plt.xticks(rotation=45)
plt.xlabel('Manufacturer')
plt.ylabel('Sales in thousands')
plt.tight_layout()
plt.show()

# %%
# 22. Boxplot of other numerical variables w.r.t manufacture
nums_cols = df.select_dtypes(include='number').columns
df_clean_numCols =df[nums_cols].dropna()

#create grid 2*2 
fig,axes= plt.subplots(2,2,figsize=(18,12))

axes = axes.flatten()
for i,col in enumerate(df_clean_numCols.columns[:4]):
  sns.boxplot(data=df,x="Manufacturer",y=col,ax=axes[i])
  axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
  
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SHIVA KUMAR\AppData\Local\Temp\ipykernel_15528\4179292116.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
# C:\Users\SHIVA KUMAR\AppData\Local\Temp\ipykernel_15528\4179292116.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
# C:\Users\SHIVA KUMAR\AppData\Local\Temp\ipykernel_15528\4179292116.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
# ...

# %%
# 23. Divide the data into input and output y=sales in
# thousand, x=all other variables

df_cleaned = df.dropna(subset='Sales in thousands')

y=df_cleaned['Sales in thousands']
# x has all other variable excepts sales in thousands...

x=df_cleaned.drop(columns=['Sales in thousands'])

print(y)
x
# Out:
# 0      16.919
# 1      39.384
# 2      14.114
# 3       8.588
# 4      20.397
#         ...
# 152     3.545
# 153    15.245
# 154    17.531
# 155     3.493
# 156    18.969
# Name: Sales in thousands, Length: 157, dtype: float64
#       Manufacturer              Model 4-year resale value Vehicle type  \
# 0    Acura          Integra                         16.36    Passenger
# 1    Acura          TL                             19.875    Passenger
# 2    Acura          CL                             18.225    Passenger
# 3    Acura          RL                             29.725    Passenger
# 4    Audi           A4                             22.255    Passenger
# ..             ...                ...                 ...          ...
# 152  Volvo          V40                                 .    Passenger
# 153  Volvo          S70                                 .    Passenger
# 154  Volvo          V70                                 .    Passenger
# ...

# %%
# 24. Encode other categorical variables using label encoder

# first copy main df to avoid the loss of data...

from sklearn.preprocessing import LabelEncoder

data_encoded = df.copy()

# take only text/object datatype 
data_encoded_cols = data_encoded.select_dtypes(include='object').columns

# use label encodes lib to map number to each category!!!
le = LabelEncoder()

for col in data_encoded_cols:
  data_encoded[col] = le.fit_transform(data_encoded[col].astype(str))
  

data_encoded.head()
# Out:
#    Manufacturer  Model  Sales in thousands  4-year resale value  Vehicle type  \
# 0             0     79              16.919                   53             1
# 1             0    143              39.384                   70             1
# 2             0     25              14.114                   63             1
# 3             0    115               8.588                   87             1
# 4             1      8              20.397                   78             1
#
#    Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50            4          17          5      9      15
# 1               28.40           16          50         36     32      83
# 2                 NaN           16          50         29     35      80
# 3               42.00           19          44         56     40      97
# 4               23.99            4          22          9     16      34
#
# ...

# %%
# 25. Encode categorical variable vehicle type using one-hot
# encoder

vehicle_encoded = pd.get_dummies(df['Vehicle type'],prefix='VehicleType')

# now concat original df and vehicle_encoded...
df_encoded = pd.concat([df,vehicle_encoded],axis=1)

df_encoded

# if no need of vehicle type col
# df_encoded.drop('Vehicle type',axis=1,inplace=True)
# df_encoded
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
vehicle_cols = [col for col in df.columns if 'vehicle' in col.lower()]
vehicle_cols
# Out:
# ['Vehicle type']

# %%
# 26.Split the data set into train and test set 70% train set
# 10% test set

from sklearn.model_selection import train_test_split

# lets say : 
'''
x as  all variables cols excepts sales in thousands,
y as only sales in thousands...
'''
x = df.drop(columns=['Sales in thousands'])
y= df[['Sales in thousands']]

print(f"x shapes before splits:{x.shape}")
print(f"y shapes before splits:{y.shape}")
print("-"*10)
# split data into 70% train 30% test...
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

print(f"shapes of x_train: {x_train.shape} and x_test: {x_test.shape}")
print(f"shapes of y_train: {y_train.shape} and y_test: {y_test.shape}")
# Out:
# x shapes before splits:(157, 14)
# y shapes before splits:(157, 1)
# ----------
# shapes of x_train: (109, 14) and x_test: (48, 14)
# shapes of y_train: (109, 1) and y_test: (48, 1)

# %%
# 27. Apply feature scaling on numerical variables

from sklearn.preprocessing import StandardScaler,MinMaxScaler

# take that x data ...which inclde numerice columns...
x_cols = x.select_dtypes(include='number').columns

# use standardScaler
# scaler = StandardScaler()
scaler=MinMaxScaler()

# fit and transform on training data (x_train) and transform on testing data(x_test)
x_train[x_cols]=scaler.fit_transform(x_train[x_cols])
x_test[x_cols]=scaler.transform(x_test[x_cols])

# %%
print(x_train)
# print(x_test)
# Out:
#       Manufacturer              Model 4-year resale value Vehicle type  \
# 140  Toyota         Tacoma                          9.575          Car
# 11   Buick          Regal                           13.74    Passenger
# 79   Mitsubishi     Mirage                          8.325    Passenger
# 68   Jeep           Cherokee                       13.775          Car
# 149  Volkswagen     GTI                             13.76    Passenger
# ..             ...                ...                 ...          ...
# 71   Lexus          GS300                          32.075    Passenger
# 106  Nissan         Xterra                              .          Car
# 14   Cadillac       DeVille                        22.525    Passenger
# 92   Mercedes-Benz  C-Class                         26.05    Passenger
# 102  Nissan         Altima                         11.295    Passenger
#
#      Price in thousands Engine size Horsepower Wheelbase Width Length  \
# ...
